# %%
pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.7/dist-packages (0.16.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)

# %%
import numpy as np 
import pandas as pd 
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.layers import LeakyReLU
import cv2
from tqdm import tqdm
import random
import math
from tensorflow.keras.utils import to_categorical

# %%
EPOCHS = 70
BATCH_SIZE = 32

# %%
df = pd.read_csv('/content/drive/MyDrive/shprjct/age_gender.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
index = 5000
image = np.fromstring(df['pixels'][index], sep = ' ', dtype = np.uint8).reshape((48,48))
plt.title(df['ethnicity'][index])
plt.imshow(image, cmap ="copper")
plt.show()

# %%
class CustomDataGen(tf.keras.utils.Sequence):
    
    def __init__(self, df,
                 batch_size = 32,
                 input_size=(48, 48, 3),
                 shuffle=True,
                 data_augmentation = False):
        self.df = df
        self.batch_size = batch_size
        self.input_size = input_size
        self.data_augmentation = data_augmentation
        self.var = 1
        
        self.imageGenerator = ImageDataGenerator(
            horizontal_flip = True,
            #vertical_flip = True,
            fill_mode = 'nearest',
            zoom_range = (1, 1.1),
            width_shift_range = 0.1,
            height_shift_range = 0.1,
            rotation_range = 10
        )
        
        self.images = []
        self.age_labels = []        
        self.ethnicity_labels = []
        self.gender_labels = []
        
        for index, row in tqdm(df.iterrows()):
            image = np.fromstring(row['pixels'], sep = ' ', dtype = np.uint8).reshape((48,48))
            image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
            
            self.images.append(image)
            
            self.age_labels.append(row['age'])
            self.ethnicity_labels.append(row['ethnicity'])
            self.gender_labels.append(row['gender'])
            
            
        self.images = np.array(self.images)
        self.age_labels = np.array(self.age_labels).astype(np.float32)
        self.ethnicity_labels = np.array(self.ethnicity_labels).astype(np.float32)
        self.gender_labels = np.array(self.gender_labels).astype(np.float32)
        
        p = np.random.permutation(len(self.age_labels))
        self.images = self.images[p]
        self.age_labels = self.age_labels[p]
        self.ethnicity_labels = to_categorical(self.ethnicity_labels[p], num_classes=5)
        self.gender_labels = self.gender_labels[p]
        
        self.n = len(self.df)
        
    
    def __getitem__(self, index):
        images = []
        
        for i in range(self.batch_size):
            image = self.images[index * self.batch_size + i]
            
            if self.data_augmentation:                
                image = self.imageGenerator.random_transform(image)
                
            images.append(image)
            
        s = slice(self.batch_size * index, (index + 1) * self.batch_size)
        return np.array(images), (self.age_labels[s], self.ethnicity_labels[s], self.gender_labels[s])
    
    def __len__(self):
            
        return self.n // self.batch_size
    
    def on_epoch_end(self):
        
        #Random permutation
        p = np.random.permutation(len(self.age_labels))
        self.images = self.images[p]
        self.age_labels = self.age_labels[p]
        self.ethnicity_labels = self.ethnicity_labels[p]
        self.gender_labels = self.gender_labels[p]

# %%
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
val = df[~msk]

train_dataset = CustomDataGen(train, data_augmentation = True)
val_dataset = CustomDataGen(val)
# Out:
# 19004it [00:03, 5326.77it/s]
# 4701it [00:00, 5910.31it/s]

# %%
train_dataset.on_epoch_end()
x, y = train_dataset[420]
print(x[21].max())
print(y[0][0], y[1][0], y[2][0])
plt.imshow(x[0])
# Out:
# 192
# 17.0 [0. 1. 0. 0. 0.] 0.0

# %%
def build_model(input_shape = (48,48,3)):
    
    i = tf.keras.layers.Input(input_shape, dtype = tf.uint8)
    x = tf.cast(i, tf.float32)
    x = tf.keras.applications.resnet50.preprocess_input(x)
    
    backbone = tf.keras.applications.resnet50.ResNet50(
                include_top=False, weights='imagenet',
                input_tensor=x
            )
    output_layer = backbone.get_layer("conv3_block3_2_conv").output    
    
    
    def build_age_branch(input_tensor): 
        x = tf.keras.layers.Dense(1024, activation = LeakyReLU(alpha=0.3))(input_tensor)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        x = tf.keras.layers.Dense(1, activation = None, name = 'age_output')(x)
    
        return x
    
    def build_etchnicity_branch(input_tensor): 
        x = tf.keras.layers.Dense(500, activation = LeakyReLU(alpha=0.3))(input_tensor)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        x = tf.keras.layers.Dense(5, activation = 'softmax', name = 'ethnicity_output')(x)
    
        return x
    
    def build_gender_branch(input_tensor): 
        x = tf.keras.layers.Dense(500, activation = LeakyReLU(alpha=0.3))(input_tensor)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        x = tf.keras.layers.Dense(1, activation = 'sigmoid', name = 'gender_output')(x)
    
        return x
    
    x = tf.keras.layers.Flatten()(output_layer)       
    output_age = build_age_branch(x)
    output_ethnicity = build_etchnicity_branch(x)
    output_gender = build_gender_branch(x)
    model = tf.keras.Model(i, [output_age, output_ethnicity, output_gender])
    
    return model

# %%
model = build_model()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step
# 94781440/94765736 [==============================] - 2s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  tf.cast (TFOpLambda)           (None, 48, 48, 3)    0           ['input_1[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 48, 48, 3)   0           ['tf.cast[0][0]']
#  ingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)    (None, 48, 48, 3)    0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  conv1_pad (ZeroPadding2D)      (None, 54, 54, 3)    0           ['tf.nn.bias_add[0][0]']
#
#  conv1_conv (Conv2D)            (None, 24, 24, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 24, 24, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 24, 24, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 26, 26, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 12, 12, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 12, 12, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 12, 12, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 12, 12, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 12, 12, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 12, 12, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 12, 12, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 12, 12, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 12, 12, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 12, 12, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 12, 12, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 12, 12, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 12, 12, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 12, 12, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 12, 12, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 12, 12, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 12, 12, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 6, 6, 128)    32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 6, 6, 128)    147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 6, 6, 512)    131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 6, 6, 512)    66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 6, 6, 512)    0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 6, 6, 512)    0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 6, 6, 128)    65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 6, 6, 128)    147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 6, 6, 512)    66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 6, 6, 512)    0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 6, 6, 512)    0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 6, 6, 128)    65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 6, 6, 128)    147584      ['conv3_block3_1_relu[0][0]']
#
#  flatten (Flatten)              (None, 4608)         0           ['conv3_block3_2_conv[0][0]']
#
#  dense (Dense)                  (None, 1024)         4719616     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 500)          2304500     ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 500)          2304500     ['flatten[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1024)        4096        ['dense[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 500)         2000        ['dense_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 500)         2000        ['dense_2[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 1024)         0           ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 500)          0           ['batch_normalization_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 500)          0           ['batch_normalization_2[0][0]']
#
#  age_output (Dense)             (None, 1)            1025        ['dropout[0][0]']
#
#  ethnicity_output (Dense)       (None, 5)            2505        ['dropout_1[0][0]']
#
#  gender_output (Dense)          (None, 1)            501         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 10,449,863
# Trainable params: 10,438,519
# Non-trainable params: 11,344
# __________________________________________________________________________________________________

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=1e-4), loss = ['mse', 'categorical_crossentropy', 'binary_crossentropy'], loss_weights = [0.001,0.5,0.5], 
              metrics = {'age_output': 'accuracy', 'ethnicity_output': 'accuracy', 'gender_output': 'accuracy'})

plateau = tf.keras.callbacks.ReduceLROnPlateau(
      monitor='val_loss', factor=0.3, patience=2, verbose = 1
)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1,
                                      patience=5)  # Early stopping (stops training when validation doesn't improve for {patience} epochs)
save_best = tf.keras.callbacks.ModelCheckpoint('weights.h5', monitor='val_loss', save_best_only=True,
                                            mode='min', save_weights_only = True)  # Saves the best version of the model to disk (as measured on the validation data set)
remote_monitor_callback = tf.keras.callbacks.RemoteMonitor(
    root='https://dweet.io', path='/dweet/for/multitask',
    send_as_json=False, field = 'data'
)     

history = model.fit(train_dataset,
            epochs=EPOCHS,
            batch_size = BATCH_SIZE,
            validation_data=val_dataset,
            callbacks = [es, save_best, plateau, remote_monitor_callback])

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.yscale('log')
plt.show()
# Out:
# Epoch 1/70
# 593/593 [==============================] - 60s 60ms/step - loss: 2.0573 - age_output_loss: 1206.3867 - ethnicity_output_loss: 1.2139 - gender_output_loss: 0.4880 - age_output_accuracy: 0.0025 - ethnicity_output_accuracy: 0.5873 - gender_output_accuracy: 0.7864 - val_loss: 1.4576 - val_age_output_loss: 806.9500 - val_ethnicity_output_loss: 0.9470 - val_gender_output_loss: 0.3544 - val_age_output_accuracy: 0.0013 - val_ethnicity_output_accuracy: 0.6969 - val_gender_output_accuracy: 0.8465 - lr: 1.0000e-04
# Epoch 2/70
# 593/593 [==============================] - 37s 62ms/step - loss: 1.4516 - age_output_loss: 824.5957 - ethnicity_output_loss: 0.8919 - gender_output_loss: 0.3622 - age_output_accuracy: 0.0013 - ethnicity_output_accuracy: 0.6979 - gender_output_accuracy: 0.8441 - val_loss: 1.1519 - val_age_output_loss: 606.3256 - val_ethnicity_output_loss: 0.7595 - val_gender_output_loss: 0.3315 - val_age_output_accuracy: 8.5616e-04 - val_ethnicity_output_accuracy: 0.7382 - val_gender_output_accuracy: 0.8583 - lr: 1.0000e-04
# Epoch 3/70
# 593/593 [==============================] - 35s 59ms/step - loss: 0.9334 - age_output_loss: 374.3144 - ethnicity_output_loss: 0.7957 - gender_output_loss: 0.3225 - age_output_accuracy: 0.0061 - ethnicity_output_accuracy: 0.7298 - gender_output_accuracy: 0.8642 - val_loss: 0.6783 - val_age_output_loss: 186.5884 - val_ethnicity_output_loss: 0.7263 - val_gender_output_loss: 0.2571 - val_age_output_accuracy: 0.0075 - val_ethnicity_output_accuracy: 0.7556 - val_gender_output_accuracy: 0.8938 - lr: 1.0000e-04
# Epoch 4/70
# 593/593 [==============================] - 35s 59ms/step - loss: 0.6808 - age_output_loss: 154.1785 - ethnicity_output_loss: 0.7536 - gender_output_loss: 0.2996 - age_output_accuracy: 0.0197 - ethnicity_output_accuracy: 0.7443 - gender_output_accuracy: 0.8739 - val_loss: 0.5800 - val_age_output_loss: 107.7432 - val_ethnicity_output_loss: 0.6918 - val_gender_output_loss: 0.2527 - val_age_output_accuracy: 0.0270 - val_ethnicity_output_accuracy: 0.7622 - val_gender_output_accuracy: 0.8923 - lr: 1.0000e-04
# Epoch 5/70
# 593/593 [==============================] - 35s 59ms/step - loss: 0.6162 - age_output_loss: 116.6756 - ethnicity_output_loss: 0.7168 - gender_output_loss: 0.2822 - age_output_accuracy: 0.0305 - ethnicity_output_accuracy: 0.7564 - gender_output_accuracy: 0.8833 - val_loss: 0.6101 - val_age_output_loss: 130.6259 - val_ethnicity_output_loss: 0.6937 - val_gender_output_loss: 0.2652 - val_age_output_accuracy: 0.0167 - val_ethnicity_output_accuracy: 0.7714 - val_gender_output_accuracy: 0.8885 - lr: 1.0000e-04
# Epoch 6/70
# 593/593 [==============================] - ETA: 0s - loss: 0.5811 - age_output_loss: 109.2639 - ethnicity_output_loss: 0.6743 - gender_output_loss: 0.2695 - age_output_accuracy: 0.0321 - ethnicity_output_accuracy: 0.7677 - gender_output_accuracy: 0.8890
# Epoch 6: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 593/593 [==============================] - 36s 60ms/step - loss: 0.5811 - age_output_loss: 109.2639 - ethnicity_output_loss: 0.6743 - gender_output_loss: 0.2695 - age_output_accuracy: 0.0321 - ethnicity_output_accuracy: 0.7677 - gender_output_accuracy: 0.8890 - val_loss: 0.6644 - val_age_output_loss: 171.0857 - val_ethnicity_output_loss: 0.7059 - val_gender_output_loss: 0.2807 - val_age_output_accuracy: 0.0441 - val_ethnicity_output_accuracy: 0.7579 - val_gender_output_accuracy: 0.8842 - lr: 1.0000e-04
# Epoch 7/70
# 593/593 [==============================] - 36s 60ms/step - loss: 0.5333 - age_output_loss: 99.4164 - ethnicity_output_loss: 0.6196 - gender_output_loss: 0.2481 - age_output_accuracy: 0.0326 - ethnicity_output_accuracy: 0.7854 - gender_output_accuracy: 0.8953 - val_loss: 0.5402 - val_age_output_loss: 104.4314 - val_ethnicity_output_loss: 0.6311 - val_gender_output_loss: 0.2404 - val_age_output_accuracy: 0.0205 - val_ethnicity_output_accuracy: 0.7847 - val_gender_output_accuracy: 0.9048 - lr: 3.0000e-05
# Epoch 8/70
# 593/593 [==============================] - 45s 75ms/step - loss: 0.5182 - age_output_loss: 96.8576 - ethnicity_output_loss: 0.6033 - gender_output_loss: 0.2394 - age_output_accuracy: 0.0318 - ethnicity_output_accuracy: 0.7914 - gender_output_accuracy: 0.9022 - val_loss: 0.5306 - val_age_output_loss: 100.8773 - val_ethnicity_output_loss: 0.6166 - val_gender_output_loss: 0.2428 - val_age_output_accuracy: 0.0336 - val_ethnicity_output_accuracy: 0.7894 - val_gender_output_accuracy: 0.9056 - lr: 3.0000e-05
# Epoch 9/70
# 593/593 [==============================] - 37s 62ms/step - loss: 0.5130 - age_output_loss: 97.8419 - ethnicity_output_loss: 0.5927 - gender_output_loss: 0.2377 - age_output_accuracy: 0.0320 - ethnicity_output_accuracy: 0.7973 - gender_output_accuracy: 0.9018 - val_loss: 0.5566 - val_age_output_loss: 122.7730 - val_ethnicity_output_loss: 0.6368 - val_gender_output_loss: 0.2308 - val_age_output_accuracy: 0.0377 - val_ethnicity_output_accuracy: 0.7857 - val_gender_output_accuracy: 0.9105 - lr: 3.0000e-05
# Epoch 10/70
# 593/593 [==============================] - 35s 59ms/step - loss: 0.5043 - age_output_loss: 94.0459 - ethnicity_output_loss: 0.5835 - gender_output_loss: 0.2370 - age_output_accuracy: 0.0323 - ethnicity_output_accuracy: 0.8015 - gender_output_accuracy: 0.9007 - val_loss: 0.5241 - val_age_output_loss: 106.3838 - val_ethnicity_output_loss: 0.6146 - val_gender_output_loss: 0.2208 - val_age_output_accuracy: 0.0259 - val_ethnicity_output_accuracy: 0.7958 - val_gender_output_accuracy: 0.9127 - lr: 3.0000e-05
# Epoch 11/70
# 593/593 [==============================] - 36s 61ms/step - loss: 0.4976 - age_output_loss: 94.9075 - ethnicity_output_loss: 0.5750 - gender_output_loss: 0.2304 - age_output_accuracy: 0.0334 - ethnicity_output_accuracy: 0.8016 - gender_output_accuracy: 0.9094 - val_loss: 0.5622 - val_age_output_loss: 137.9765 - val_ethnicity_output_loss: 0.6205 - val_gender_output_loss: 0.2279 - val_age_output_accuracy: 0.0203 - val_ethnicity_output_accuracy: 0.7949 - val_gender_output_accuracy: 0.9069 - lr: 3.0000e-05
# Epoch 12/70
# 593/593 [==============================] - 35s 60ms/step - loss: 0.4905 - age_output_loss: 93.4717 - ethnicity_output_loss: 0.5685 - gender_output_loss: 0.2255 - age_output_accuracy: 0.0319 - ethnicity_output_accuracy: 0.8023 - gender_output_accuracy: 0.9081 - val_loss: 0.5192 - val_age_output_loss: 104.4850 - val_ethnicity_output_loss: 0.6040 - val_gender_output_loss: 0.2254 - val_age_output_accuracy: 0.0321 - val_ethnicity_output_accuracy: 0.7956 - val_gender_output_accuracy: 0.9065 - lr: 3.0000e-05
# Epoch 13/70
# 593/593 [==============================] - 35s 60ms/step - loss: 0.4841 - age_output_loss: 92.8306 - ethnicity_output_loss: 0.5614 - gender_output_loss: 0.2211 - age_output_accuracy: 0.0322 - ethnicity_output_accuracy: 0.8085 - gender_output_accuracy: 0.9107 - val_loss: 0.4981 - val_age_output_loss: 94.8595 - val_ethnicity_output_loss: 0.5779 - val_gender_output_loss: 0.2285 - val_age_output_accuracy: 0.0139 - val_ethnicity_output_accuracy: 0.8063 - val_gender_output_accuracy: 0.9097 - lr: 3.0000e-05
# Epoch 14/70
# 593/593 [==============================] - 35s 60ms/step - loss: 0.4765 - age_output_loss: 89.9115 - ethnicity_output_loss: 0.5560 - gender_output_loss: 0.2171 - age_output_accuracy: 0.0340 - ethnicity_output_accuracy: 0.8087 - gender_output_accuracy: 0.9126 - val_loss: 0.5168 - val_age_output_loss: 95.5719 - val_ethnicity_output_loss: 0.6146 - val_gender_output_loss: 0.2278 - val_age_output_accuracy: 0.0325 - val_ethnicity_output_accuracy: 0.7937 - val_gender_output_accuracy: 0.9022 - lr: 3.0000e-05
# Epoch 15/70
# 593/593 [==============================] - ETA: 0s - loss: 0.4765 - age_output_loss: 91.3755 - ethnicity_output_loss: 0.5476 - gender_output_loss: 0.2226 - age_output_accuracy: 0.0314 - ethnicity_output_accuracy: 0.8120 - gender_output_accuracy: 0.9076
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 593/593 [==============================] - 36s 60ms/step - loss: 0.4765 - age_output_loss: 91.3755 - ethnicity_output_loss: 0.5476 - gender_output_loss: 0.2226 - age_output_accuracy: 0.0314 - ethnicity_output_accuracy: 0.8120 - gender_output_accuracy: 0.9076 - val_loss: 0.5120 - val_age_output_loss: 99.5158 - val_ethnicity_output_loss: 0.6035 - val_gender_output_loss: 0.2213 - val_age_output_accuracy: 0.0231 - val_ethnicity_output_accuracy: 0.7964 - val_gender_output_accuracy: 0.9099 - lr: 3.0000e-05
# Epoch 16/70
# 593/593 [==============================] - 35s 60ms/step - loss: 0.4500 - age_output_loss: 86.7397 - ethnicity_output_loss: 0.5221 - gender_output_loss: 0.2044 - age_output_accuracy: 0.0310 - ethnicity_output_accuracy: 0.8191 - gender_output_accuracy: 0.9177 - val_loss: 0.4901 - val_age_output_loss: 91.2772 - val_ethnicity_output_loss: 0.5820 - val_gender_output_loss: 0.2157 - val_age_output_accuracy: 0.0280 - val_ethnicity_output_accuracy: 0.8029 - val_gender_output_accuracy: 0.9152 - lr: 9.0000e-06
# Epoch 17/70
# 593/593 [==============================] - 39s 66ms/step - loss: 0.4477 - age_output_loss: 86.3776 - ethnicity_output_loss: 0.5174 - gender_output_loss: 0.2051 - age_output_accuracy: 0.0319 - ethnicity_output_accuracy: 0.8204 - gender_output_accuracy: 0.9182 - val_loss: 0.4811 - val_age_output_loss: 87.8513 - val_ethnicity_output_loss: 0.5699 - val_gender_output_loss: 0.2166 - val_age_output_accuracy: 0.0255 - val_ethnicity_output_accuracy: 0.8065 - val_gender_output_accuracy: 0.9135 - lr: 9.0000e-06
# Epoch 18/70
# 593/593 [==============================] - 37s 63ms/step - loss: 0.4490 - age_output_loss: 88.4931 - ethnicity_output_loss: 0.5128 - gender_output_loss: 0.2083 - age_output_accuracy: 0.0327 - ethnicity_output_accuracy: 0.8202 - gender_output_accuracy: 0.9161 - val_loss: 0.4932 - val_age_output_loss: 98.1305 - val_ethnicity_output_loss: 0.5716 - val_gender_output_loss: 0.2185 - val_age_output_accuracy: 0.0315 - val_ethnicity_output_accuracy: 0.8078 - val_gender_output_accuracy: 0.9146 - lr: 9.0000e-06
# Epoch 19/70
# 593/593 [==============================] - ETA: 0s - loss: 0.4497 - age_output_loss: 86.0896 - ethnicity_output_loss: 0.5214 - gender_output_loss: 0.2058 - age_output_accuracy: 0.0338 - ethnicity_output_accuracy: 0.8186 - gender_output_accuracy: 0.9169
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 593/593 [==============================] - 35s 59ms/step - loss: 0.4497 - age_output_loss: 86.0896 - ethnicity_output_loss: 0.5214 - gender_output_loss: 0.2058 - age_output_accuracy: 0.0338 - ethnicity_output_accuracy: 0.8186 - gender_output_accuracy: 0.9169 - val_loss: 0.4913 - val_age_output_loss: 94.0334 - val_ethnicity_output_loss: 0.5776 - val_gender_output_loss: 0.2170 - val_age_output_accuracy: 0.0246 - val_ethnicity_output_accuracy: 0.8082 - val_gender_output_accuracy: 0.9163 - lr: 9.0000e-06
# Epoch 20/70
# 593/593 [==============================] - 38s 63ms/step - loss: 0.4397 - age_output_loss: 85.7186 - ethnicity_output_loss: 0.5035 - gender_output_loss: 0.2046 - age_output_accuracy: 0.0324 - ethnicity_output_accuracy: 0.8249 - gender_output_accuracy: 0.9179 - val_loss: 0.4830 - val_age_output_loss: 92.7551 - val_ethnicity_output_loss: 0.5719 - val_gender_output_loss: 0.2086 - val_age_output_accuracy: 0.0255 - val_ethnicity_output_accuracy: 0.8084 - val_gender_output_accuracy: 0.9170 - lr: 2.7000e-06
# Epoch 21/70
# 593/593 [==============================] - ETA: 0s - loss: 0.4410 - age_output_loss: 87.0630 - ethnicity_output_loss: 0.5038 - gender_output_loss: 0.2041 - age_output_accuracy: 0.0334 - ethnicity_output_accuracy: 0.8298 - gender_output_accuracy: 0.9197
# Epoch 21: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# 593/593 [==============================] - 38s 64ms/step - loss: 0.4410 - age_output_loss: 87.0630 - ethnicity_output_loss: 0.5038 - gender_output_loss: 0.2041 - age_output_accuracy: 0.0334 - ethnicity_output_accuracy: 0.8298 - gender_output_accuracy: 0.9197 - val_loss: 0.4891 - val_age_output_loss: 96.3373 - val_ethnicity_output_loss: 0.5713 - val_gender_output_loss: 0.2142 - val_age_output_accuracy: 0.0263 - val_ethnicity_output_accuracy: 0.8116 - val_gender_output_accuracy: 0.9174 - lr: 2.7000e-06
# Epoch 22/70
# 593/593 [==============================] - 35s 60ms/step - loss: 0.4383 - age_output_loss: 87.0958 - ethnicity_output_loss: 0.4999 - gender_output_loss: 0.2025 - age_output_accuracy: 0.0322 - ethnicity_output_accuracy: 0.8275 - gender_output_accuracy: 0.9195 - val_loss: 0.4897 - val_age_output_loss: 97.4339 - val_ethnicity_output_loss: 0.5707 - val_gender_output_loss: 0.2137 - val_age_output_accuracy: 0.0287 - val_ethnicity_output_accuracy: 0.8116 - val_gender_output_accuracy: 0.9178 - lr: 8.1000e-07
# Epoch 22: early stopping

# %%
model.load_weights('weights.h5')
model.evaluate(val_dataset)
model.summary()
# Out:
# 146/146 [==============================] - 3s 18ms/step - loss: 0.4802 - age_output_loss: 88.0456 - ethnicity_output_loss: 0.5692 - gender_output_loss: 0.2152 - age_output_accuracy: 0.0253 - ethnicity_output_accuracy: 0.8069 - gender_output_accuracy: 0.9144
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  tf.cast (TFOpLambda)           (None, 48, 48, 3)    0           ['input_1[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 48, 48, 3)   0           ['tf.cast[0][0]']
#  ingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)    (None, 48, 48, 3)    0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  conv1_pad (ZeroPadding2D)      (None, 54, 54, 3)    0           ['tf.nn.bias_add[0][0]']
#
#  conv1_conv (Conv2D)            (None, 24, 24, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 24, 24, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 24, 24, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 26, 26, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 12, 12, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 12, 12, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 12, 12, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 12, 12, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 12, 12, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 12, 12, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 12, 12, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 12, 12, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 12, 12, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 12, 12, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 12, 12, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 12, 12, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 12, 12, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 12, 12, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 12, 12, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 12, 12, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 12, 12, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 6, 6, 128)    32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 6, 6, 128)    147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 6, 6, 512)    131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 6, 6, 512)    66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 6, 6, 512)    0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 6, 6, 512)    0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 6, 6, 128)    65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 6, 6, 128)    147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 6, 6, 512)    66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 6, 6, 512)    0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 6, 6, 512)    0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 6, 6, 128)    65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 6, 6, 128)    147584      ['conv3_block3_1_relu[0][0]']
#
#  flatten (Flatten)              (None, 4608)         0           ['conv3_block3_2_conv[0][0]']
#
#  dense (Dense)                  (None, 1024)         4719616     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 500)          2304500     ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 500)          2304500     ['flatten[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1024)        4096        ['dense[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 500)         2000        ['dense_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 500)         2000        ['dense_2[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 1024)         0           ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 500)          0           ['batch_normalization_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 500)          0           ['batch_normalization_2[0][0]']
#
#  age_output (Dense)             (None, 1)            1025        ['dropout[0][0]']
#
#  ethnicity_output (Dense)       (None, 5)            2505        ['dropout_1[0][0]']
#
#  gender_output (Dense)          (None, 1)            501         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 10,449,863
# Trainable params: 10,438,519
# Non-trainable params: 11,344
# __________________________________________________________________________________________________

# %%
name_genders = ['male', 'female']

# %%
images, labels = val_dataset[25]
index = 0

p = model.predict(images)

gender_predictions = tf.where(p[2] > 0.5, 1, 0)
plt.title(f'Prediction: {p[0][index].astype(np.int)[0]} years, {name_genders[gender_predictions[index][0]]}\n'+
         f'Real: {int(labels[0][index])} years,{name_genders[int(labels[2][index])]}')
plt.imshow(images[index])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   import sys

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)
